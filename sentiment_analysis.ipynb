# %% [markdown]
# <a href="https://colab.research.google.com/github/sanjida-k/Shadowfox/blob/main/sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vaderSentiment matplotlib pandas

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = "task2.csv"   # make sure the file is in the same folder
df = pd.read_csv(file_path)

# Display basic info
print("🔹 First 5 Rows:")
print(df.head())
print("\n🔹 Dataset Info:")
print(df.info())
print("\n🔹 Summary Statistics:")
print(df.describe())

# Check for missing values
print("\n🔹 Missing Values:")
print(df.isnull().sum())

# Handle missing values (optional)
df = df.dropna()  # or df.fillna(method='ffill') to forward fill

# Check for duplicates
print("\n🔹 Duplicate Rows:", df.duplicated().sum())
df = df.drop_duplicates()

# Plot distributions of numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
df[num_cols].hist(figsize=(10, 8), bins=15)
plt.suptitle("Distribution of Numerical Columns")
plt.show()

# Correlation heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df[num_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Heatmap")
plt.show()

# Countplot for categorical columns
cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    plt.figure(figsize=(6, 4))
    sns.countplot(data=df, x=col)
    plt.title(f"Countplot of {col}")
    plt.xticks(rotation=45)
    plt.show()

print("\n✅ Data Cleaning and EDA Completed Successfully!")
# Out:
# 🔹 First 5 Rows:
#                                                 text  sentiment
# 0  The situation in Gaza is heartbreaking. Innoce...          0
# 1  Praying for peace and justice in Palestine. #F...          1
# 2  Israel's actions amount to genocide, the world...          1
# 3  Hope for a ceasefire soon to end the suffering...          1
# 4  The conflict is complex, both sides have suffe...         -1
#
# 🔹 Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   text       150 non-null    object
#  1   sentiment  150 non-null    int64
# dtypes: int64(1), object(1)
# memory usage: 2.5+ KB
# None
#
# 🔹 Summary Statistics:
#         sentiment
# count  150.000000
# mean     0.313333
# std      0.875748
# min     -1.000000
# 25%     -1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000
#
# 🔹 Missing Values:
# ...
